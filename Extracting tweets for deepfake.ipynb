# %%
import os
import tweepy as tw
import pandas as pd
import csv 

access_token = 'xxxxxxxxxxx'
access_token_secret = 'xxxxxxxxxxxxxxxxxxxx'
consumer_key = 'xxxxxxxxxxxxxxx'
consumer_secret = 'xxxxxxxxxxxxxxxxx'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)
  
search_words = "#deepfake", "deepfake", "AI misinformation"
date_since = "2017-01-01"

tweets_text = []

tweets = tw.Cursor(api.search,
              q=search_words ,
              lang="en",
              since=date_since).items(5000)

for tweet in tweets:
    tweets_text.append([tweet.user.screen_name, tweet.created_at, tweet.text, tweet.in_reply_to_screen_name])
    
 
df_Tweet = pd.DataFrame(tweets_text)
df_Tweet.to_csv('DF.csv', header=[tweet.user.screen_name, tweet.created_at, tweet.text, tweet.in_reply_to_screen_name], index=False,)
df_Tweet.head()
# Out:
#                  0                   1  \
# 0    DeepFakeNews1 2021-06-02 09:45:03
# 1  ReImagineEuropa 2021-06-02 09:33:01
# 2   education_24x7 2021-06-01 18:03:29
# 3    DeepFakeNews1 2021-06-01 16:15:03
# 4      tlloydjones 2021-06-01 16:08:02
#
#                                                    2     3
# 0  RT @ReImagineEuropa: Seeing is believing?🤖 Dee...  None
# 1  Seeing is believing?🤖 Deepfakes and AI-generat...  None
# 2  RT @SynFutures: #Deepfake Maps Could Really Me...  None
# 3  RT @tlloydjones: Researchers experimented by a...  None
# 4  Researchers experimented by applying #AI techn...  None
